# %%
import pandas as pd ; 
import numpy as np ; 
from matplotlib import pyplot as plt ; 
import os , sys , subprocess , time  ; 


class quadratic:

    def __init__(self):
        self.hypothesis = "fib(n) = w1 * x1^2  + w2 * x1 + b"
        self.w1 =  np.random.uniform() ;
        self.w2 = np.random.uniform() ; 
        self.b = np.random.uniform() ; 
        self.data = np.genfromtxt('./fibonacci' , delimiter=',' , dtype='int') ; 
        self.features = self.data[: , 0] ; 
        self.target = self.data[: , 1]
        self.alpha = 0.00000000032389329 ;
    
    def __update_hyp__(self):
        self.hyp = self.get_hyp() ; 
        pass ;  

    def get_hyp(self):
        return self.w1 * self.features**2 + self.w2 * self.features + self.b  ;

    
    def cost(self):
        return ((self.hyp-self.target)**2).mean() ; 
    
    def train(self):
        for counter in range(100000):
            self.__update_hyp__() ;
            for row in range(self.features.shape[0]):
                dcost_dhyp = 2*(self.hyp[row] - self.target[row]) ;
                dhyp_dw1 = self.features[row]**2  ;
                dhyp_dw2 = self.features[row] ; 
                
                self.w1 -= self.alpha * dcost_dhyp * dhyp_dw1 ;
                self.w2 -= self.alpha * dcost_dhyp * dhyp_dw2 ; 
                self.b -= self.alpha * dcost_dhyp * 1 ;

            if not counter%1000:
                print(self.cost()) ;
#                 plt.scatter(self.features , self.target , c = 'b' , alpha = 0.9 , linewidths=5 ) ; 
#                 plt.scatter(self.features , self.hyp , c= 'r' , edgecolors="g") ;

# %%
obj = fibonacii() 
obj.train()
# Out:
# 142839.850808
# 2731.99658843
# 2660.29530126
# 2590.47782893
# 2522.49467775
# 2456.2976544
# 2391.83983175
# 2329.07551558
# 2267.9602122
# 2208.45059692
# 2150.50448331
# 2094.08079332
# 2039.13952814
# 1985.64173986
# 1933.54950385
# 1882.82589187
# 1833.43494592
# 1785.34165271
# 1738.51191887
# 1692.91254675
# 1648.51121093
# 1605.27643526
# 1563.17757059
# 1522.18477298
# 1482.26898262
# 1443.40190318
# 1405.55598176
# 1368.70438935
# 1332.82100185
# 1297.88038149
# 1263.85775884
# 1230.72901526
# 1198.47066575
# 1167.05984236
# 1136.47427794
# 1106.69229036
# 1077.69276716
# 1049.45515057
# 1021.95942292
# 995.186092497
# 969.116179666
# 943.73120346
# 919.013168463
# 894.944552054
# 871.508291984
# 848.687774286
# 826.466821492
# 804.829681164
# 783.761014733
# 763.245886621
# 743.269753653
# 723.81845475
# 704.878200887
# 686.435565321
# 668.47747407
# 650.991196648
# 633.964337037
# 617.384824901
# 601.240907031
# 585.521139008
# 570.214377098
# 555.309770343
# 540.796752876
# 526.665036429
# 512.904603037
# 499.505697938
# 486.458822659
# 473.754728282
# 461.384408885
# 449.339095162
# 437.6102482
# 426.189553435
# 415.068914748
# 404.240448733
# 393.696479104
# 383.429531256
# 373.432326965
# 363.697779229
# 354.218987241
# 344.989231502
# 336.001969057
# 327.25082885
# 318.729607216
# 310.432263478
# 302.352915668
# 294.485836354
# 286.825448582
# 279.366321922
# 272.103168619
# 265.030839842
# 258.144322037
# 251.438733372
# 244.909320276
# 238.551454067
# 232.360627676
# 226.332452446
# 220.462655025
# 214.747074336
# 209.181658625
# 203.76246259

# %%
params = obj.w1 , obj.w2 , obj.b ;

# %%
params
# Out:
# (1.0140132261764279, 2.8175142968526621, 1.0057765038039639)
